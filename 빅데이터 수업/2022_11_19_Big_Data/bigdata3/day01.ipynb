# %% [markdown]
# # 7\. Visualization

# %% [markdown]
# ## 7.1 matplotlib
#
# reference: https://matplotlib.org/stable/plot_types/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Scatter Plots
# 데이터가 어떻게 분포하고 있는지 확인할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make the data
# x = 4 + np.random.normal(0, 2, 24)
# y = 4 + np.random.normal(0, 2, len(x))
#
# # size and color:
# sizes = np.random.uniform(15, 80, len(x))
# colors = np.random.uniform(15, 80, len(x))
#
# # plot
# fig, ax = plt.subplots()
# ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, (len(x)))

sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# %%
plt.scatter(x, y, s=sizes, c=colors)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax1.scatter(x, y)

ax2 = fig.add_subplot(2, 1, 2)
ax2.scatter(x, y)

plt.show()

# %% [markdown]
# #### Bar Charts
# 범주별 빈도를 확인할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data:
# x = 0.5 + np.arange(8)
# y = np.random.uniform(2, 7, len(x))
#
# # plot
# fig, ax = plt.subplots()
#
# ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x = 0.5 * np.arange(8)
y = np.random.uniform(2, 10, len(x))

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# #### Line Chart
# 시간의 흐름에 따른 변화를 보고자할 때 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data
# x = np.linspace(0, 10, 100)
# y = 4 + 2 * np.sin(2 * x)
#
# # plot
# fig, ax = plt.subplots()
#
# ax.plot(x, y, linewidth=2.0)
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 8), yticks=np.arange(1, 8)
#   )
#
# plt.show()
# ```

# %%
x = np.linspace(0, 10, 100)
y = 4 + 2*np.sin(2*x)

plt.plot(x, y)

# %% [markdown]
# #### Box Plots
# 변수의 이상치 및 특징을 파악하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# plt.style.use('_mpl-gallery')
#
# # make data:
# data = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))
#
# # plot
# fig, ax = plt.subplots()
# box_plot = ax.boxplot(
#   data,
#   positions=[2, 4, 6],
#   widths=1.5, patch_artist=True,
#   showmeans=False, showfliers=False,
#   medianprops={"color": "white", "linewidth": 0.5},
#   boxprops={
#     "facecolor": "C0", "edgecolor": "white", "linewidth": 0.5},
#   whiskerprops={"color": "C0", "linewidth": 1.5},
#   capprops={"color": "C0", "linewidth": 1.5}
#   )
#
# plt.show()
# ```

# %%
data = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e6b1c73220>,
#   <matplotlib.lines.Line2D at 0x1e6b1c734f0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c7f640>,
#   <matplotlib.lines.Line2D at 0x1e6b1c7f910>,
#   <matplotlib.lines.Line2D at 0x1e6b1c8aa30>,
#   <matplotlib.lines.Line2D at 0x1e6b1c8ad00>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e6b1c737c0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c73ac0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c7fbe0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c7feb0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c8afd0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c962e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e6b1c64f10>,
#   <matplotlib.lines.Line2D at 0x1e6b1c7f370>,
#   <matplotlib.lines.Line2D at 0x1e6b1c8a760>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e6b1c73d90>,
#   <matplotlib.lines.Line2D at 0x1e6b1c8a1c0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c965b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e6b1c7f0a0>,
#   <matplotlib.lines.Line2D at 0x1e6b1c8a490>,
#   <matplotlib.lines.Line2D at 0x1e6b1c96880>],
#  'means': []}

# %% [markdown]
# #### Pie Charts
# 카테고리별 비율을 시각화하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
#
# # Pie chart, where the slices will be ordered and plotted counter-clockwise:
# labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
# sizes = [15, 30, 45, 10]
# explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice
#
# fig1, ax1 = plt.subplots()
# ax1.pie(
#   sizes,
#   explode=explode,
#   labels=labels,
#   autopct='%1.1f%%',
#   shadow=True,
#   startangle=90
#   )
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# plt.show()
# ```

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
counts = [15, 30, 45, 10]
explode = (0, 0.4, 0, 0)

plt.pie(counts, labels=labels, explode=explode, startangle=90, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e6b1dee250>,
#   <matplotlib.patches.Wedge at 0x1e6b1dee970>,
#   <matplotlib.patches.Wedge at 0x1e6b1dfb0d0>,
#   <matplotlib.patches.Wedge at 0x1e6b1dfb7f0>],
#  [Text(-0.4993895680663527, 0.9801071672559598, 'Frogs'),
#   Text(-1.4265847397240157, -0.4635255984156244, 'Hogs'),
#   Text(0.9801072140121813, -0.4993894763020948, 'Dogs'),
#   Text(0.33991864973549485, 1.0461621822461364, 'Logs')],
#  [Text(-0.2723943098543742, 0.5346039094123416, '15.0%'),
#   Text(-0.9510564931493437, -0.30901706561041625, '30.0%'),
#   Text(0.5346039349157352, -0.27239425980114257, '45.0%'),
#   Text(0.1854101725829972, 0.5706339175888016, '10.0%')])

# %% [markdown]
# #### Histograms
# 데이터의 분포를 확인하기 위해 사용
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # make data
# x = 4 + np.random.normal(0, 1.5, 200)
#
# # plot:
# fig, ax = plt.subplots()
#
# ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")
#
# ax.set(
#   xlim=(0, 8), xticks=np.arange(1, 8),
#   ylim=(0, 56), yticks=np.linspace(0, 56, 9))
#
# plt.show()
# ```

# %%
x = 4 + np.random.normal(0, 2, 1000)

plt.hist(x, bins=20)
# Out:
# (array([  8.,   7.,  10.,  32.,  32.,  57.,  62.,  81., 119.,  98., 112.,
#         110.,  87.,  64.,  38.,  32.,  24.,  18.,   3.,   6.]),
#  array([-1.61573996, -1.04905912, -0.48237828,  0.08430256,  0.6509834 ,
#          1.21766424,  1.78434507,  2.35102591,  2.91770675,  3.48438759,
#          4.05106843,  4.61774927,  5.18443011,  5.75111095,  6.31779179,
#          6.88447263,  7.45115347,  8.01783431,  8.58451515,  9.15119599,
#          9.71787683]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## 7.2 seaborn
#
# reference: https://seaborn.pydata.org

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='whitegrid')

# %% [markdown]
# ### Scatter Plots
# x가 continous한 값이라면 산점도 <br>
# x가 categorical 값이라면 jitter <br>
# <br>
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - style: 카테고리별 다른 그림으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
#
# sns.relplot(
#     data=tips,
#     x="total_bill", y="tip", hue="smoker", style="time",
# )
# ```

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# %matplotlib inline

# %%
sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    style='sex',
    hue='smoker'
)

# %%
sns.relplot(
    data=tips,
    x='sex',
    y='tip',
)

# %% [markdown]
# ### Bar Charts
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - x: x를 쓰면 일반적인 수직 그래프
#   - y: y를 쓰면 수평 그래프
#   - kind='count': 빈도 계산
#   - palette='pastel': 다양한 색상을 입힘
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# titanic = sns.load_dataset("titanic")
#
# sns.catplot(
#     data=titanic,
#     x="deck", hue="class", kind="count",
#     palette="pastel",
# )
# ```

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.catplot(
    data=titanic,
    x='deck',
    kind='count',
    hue='sex'
)

# %% [markdown]
# ### Line Charts
#
# >
# x가 continous한 값이라면 일반적 시계열 모양 <br>
# x가 중복된 값을 가지고 있으면 95% 신뢰구간을 표현 <br>
# <br>
# args
#   - errorbar
#     - None: 신뢰구간 제거
#     - sd: 표준편차 신뢰구간
#   - hue: 그룹 별 다른 색상으로 plot
#   - style: 카테고리별 다른 그림으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# dowjones = sns.load_dataset("dowjones")
# sns.relplot(data=dowjones, x="Date", y="Price", kind="line")
#
# fmri = sns.load_dataset("fmri")
# sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")
# ```

# %%
dowjones = sns.load_dataset('dowjones')

# %%
sns.relplot(
    data=dowjones,
    x='Date',
    y='Price',
    kind='line'
)

# %% [markdown]
# ### Box Plots
# >
# args
#   - hue: 그룹 별 다른 색상으로 plot
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
# sns.catplot(data=tips, x="day", y="total_bill")                           # 점도표
# sns.catplot(data=tips, x="day", y="total_bill", kind="box")               # boxplot
# sns.catplot(
#   data=tips, x="total_bill", y="day", hue="sex",
#   kind="violin", split=True
#   ) # violin
# ```

# %%
tips = sns.load_dataset('tips')

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='tip',
    kind='box'
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    hue='sex',
    kind='box'
)

# %% [markdown]
# ### Histograms
# >
# args
#   - binwidth: 구간 범위 설정
#   - hue: 그룹 별 다른 색상으로 plot
#   - multiple: 다른 그룹을 어떻게 표현할지 설정
#     - stack: 합하여 출력
#     - dodge: 분리하여 출력
#   - col: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#   - stats: 어떤 통계지표로 출력할지 출력
#     - density: 밀도 출력
#     - probability: 확률 출력
#
# ```python
# penguins = sns.load_dataset("penguins")
# sns.displot(penguins, x="flipper_length_mm", binwidth=3, hue='species', multiple='dodge', stat='density')
# ```

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins = penguins.dropna()

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    binwidth=3,
    hue='species',
    stat='density'
)

# %% [markdown]
# ### Distplots
# >args
#   - kind: 어떤 타입을 출력할지 설정
#     - kde: 커널 분포 출력
#     - ecdf: 누적 분포 출력
#   - hue: 그룹 별 다른 색상으로 plot
#   - multiple: 다른 그룹을 어떻게 표현할지 설정
#     - stack: 합하여 출력
#     - dodge: 분리하여 출력
#   - fill: bool: 면적을 채울지 설정
#
# ```python
# sns.displot(penguins, x="flipper_length_mm", kind="kde")
# ```
# <br>
#
#
# **joint plot**
# ```python
# sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
#
# sns.jointplot(
#     data=penguins,
#     x="bill_length_mm", y="bill_depth_mm", hue="species",
#     kind="kde"
# )
#
# ```

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    kind='kde'
)

# %%
sns.jointplot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
)

# %%
sns.jointplot(
    data=penguins,
    x='flipper_length_mm',
    y='bill_depth_mm',
    hue='species',
    kind='kde'
)

# %% [markdown]
# ### Heatmaps
# >
# args
# - cmap: colormap 설정
#   - Blues
#   - Reds
#   - YlGnBu
#
# ```python
# normal_data = np.random.randn(10, 12)
# ax = sns.heatmap(normal_data)
# ```

# %%
data = np.random.randn(10, 12)
sns.heatmap(
    data=data,
    cmap='PiYG_r'
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Model
# >
# args
# - y_jitter: y값의 출력 옵션 설정
# - hue: 그룹 별 다른 색상으로 plot
# - markers: 어떤 모양으로 표현할지 설정
# - logistic: bool
#   - True: logistic regression plot
# - lowess
#   - True: nonparametric regression by lowess
# - col: 해당 컬럼의 값을 기준으로 분할하여 plot
# - row: 해당 컬럼의 값을 기준으로 분할하여 plot
#
# ```python
# tips = sns.load_dataset("tips")
# sns.lmplot(x="total_bill", y="tip", data=tips)
#
# tips["big_tip"] = (tips.tip / tips.total_bill) > .15
# sns.lmplot(x="total_bill", y="big_tip", data=tips, y_jitter=.03, logistic=True)
# ```
# <br>
#
# **joint plot**
# ```python
# sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");
# ```
#
# **pair plot**
# ```python
# sns.pairplot(tips, x_vars=["total_bill", "size"], y_vars=["tip"],
#              hue="smoker", height=5, kind="reg");
# ```

# %%
tips = sns.load_dataset('tips')
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(
    data=tips,
    x='total_bill',
    y='tip',
    kind='reg'
)

# %%
sns.pairplot(
    data=tips,
    x_vars=['total_bill', 'size'], 
    y_vars=['tip'],
    hue='smoker',
    kind='reg',
    height=10
)
